# %%
pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# ...
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# ...
#   Using cached prettytable-0.7.2.zip (28 kB)
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=fc70c86214ee4871db077f7db898118ed79921130598616158b36df0a8d86088
#   Stored in directory: c:\users\birhane\appdata\local\pip\cache\wheels\75\f7\28\77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\birhane\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import pyodbc
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
# %load_ext sql

# %%
# %sql mssql+pyodbc://AntiLaundering:AntiLaundering@pyodbc

# %%
{
    "tags": [
        "output_scroll",
    ]
}
# Out:
# {'tags': ['output_scroll']}

# %%
# %%sql
# SELECT top(1000) [TXN_ID]
#       ,[TOTAL_TNX]
#       ,[SUSPECTFRAUD]
#       ,[DEBIT_CUSTOMER]
#       ,[USD_EQUIV_BALANCE]
#       ,[CREDIT_AMOUNT]
#       ,[AGE]
#       ,[GENDER]
#       ,[REGIONNAME]
#       ,[DISTRICTNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND]
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(1, 8, 0, 4599132, Decimal('29827.8000'), Decimal('1577540.0000'), 42, 'MALE', 'OROMIYA', 'MERKATO'),
#  (2, 4, 0, 4530324, Decimal('5545.9700'), Decimal('292500.0000'), 47, 'MALE', 'BENSHANGUL GUMUZ', 'NEKEMTE'),
#  (3, 11, 0, 1456210, Decimal('4705.6500'), Decimal('248200.0000'), 56, 'MALE', 'OROMIYA', 'MEGENAGNA'),
#  (5, 6, 0, 947470, Decimal('20301.8700'), Decimal('1077000.0000'), 46, 'MALE', 'SWER', 'JIMMA'),
#  (6, 6, 0, 4400157, Decimal('2333.2600'), Decimal('123410.0000'), 52, 'MALE', 'ADDIS ABABA', 'YEKA'),
#  (7, 79, 1, 3646553, Decimal('19257.0000'), Decimal('1017125.5300'), 64, 'MALE', 'SWER', 'SHASHEMENE'),
#  (8, 4, 0, 3936320, Decimal('625.5200'), Decimal('33000.0000'), 45, 'MALE', 'OROMIYA', 'SEMERA'),
#  (9, 4, 0, 843483, Decimal('720.6200'), Decimal('38200.0000'), 47, 'MALE', 'SNNP', 'SHASHEMENE'),
#  (10, 9, 0, 4434072, Decimal('2441.8400'), Decimal('129500.0000'), 53, 'MALE', 'OROMIYA', 'YEKA'),
# ...

# %%
# %%sql
# SELECT count([TXN_ID]) total_txn
#       ,[GENDER]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by GENDER order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(1323688, 'MALE'), (169870, 'FEMALE')]

# %%
xx=%sql SELECT count([TXN_ID]) total_txn,[SUSPECTFRAUD],[GENDER]FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by GENDER,[SUSPECTFRAUD] order by count([TXN_ID]) desc;
xx
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(1311850, 0, 'MALE'),
#  (169864, 0, 'FEMALE'),
#  (11838, 1, 'MALE'),
#  (6, 1, 'FEMALE')]

# %%
plt.bar(xx.columns, values.rows, color ='maroon',
        width = 0.4)
 
plt.xlabel("Money Laundering by gender")
plt.ylabel("No. Customers")
plt.title("Money Laundering by gender")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 plt.bar(xx.columns, values.rows, color ='maroon',
#       2         width = 0.4)
#       4 plt.xlabel("Money Laundering by gender")
#       5 plt.ylabel("No. Customers")
#
# File C:\Anaconda\lib\site-packages\matplotlib\_api\__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'bar'

# %%
# %%sql
# SELECT count([TXN_ID]) total_txn,[SUSPECTFRAUD]
#       ,[GENDER]
#       ,[REGIONNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by [GENDER],[SUSPECTFRAUD]
#       ,[REGIONNAME] order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(399673, 0, 'MALE', 'OROMIYA'),
#  (329531, 0, 'MALE', 'ADDIS ABABA'),
#  (211754, 0, 'MALE', 'AMHARA'),
#  (148322, 0, 'MALE', 'SNNP'),
#  (83269, 0, 'FEMALE', 'ADDIS ABABA'),
#  (55048, 0, 'MALE', 'SOMALE'),
#  (49934, 0, 'MALE', 'SIDAMA'),
#  (33922, 0, 'FEMALE', 'OROMIYA'),
#  (33412, 0, 'MALE', 'SWER'),
#  (25095, 0, 'FEMALE', 'AMHARA'),
#  (23915, 0, 'MALE', 'TIGRAY'),
#  (20807, 0, 'MALE', 'DIRE DAWA'),
#  (13251, 0, 'MALE', 'AFAR'),
#  (13210, 0, 'MALE', 'BENSHANGUL GUMUZ'),
#  (11500, 0, 'FEMALE', 'SNNP'),
#  (7977, 0, 'MALE', 'HARARI'),
#  (5016, 0, 'MALE', 'GAMBELLA'),
#  (4749, 0, 'FEMALE', 'SIDAMA'),
#  (3509, 1, 'MALE', 'SNNP'),
#  (2741, 0, 'FEMALE', 'DIRE DAWA'),
#  (2390, 0, 'FEMALE', 'SOMALE'),
#  (2155, 1, 'MALE', 'TIGRAY'),
#  (1902, 1, 'MALE', 'OROMIYA'),
#  (1806, 1, 'MALE', 'SWER'),
#  (1525, 0, 'FEMALE', 'SWER'),
#  (1406, 1, 'MALE', 'SOMALE'),
#  (1267, 0, 'FEMALE', 'HARARI'),
# ...

# %%
# %%sql
# SELECT count([TXN_ID]) total_txn
#       ,[GENDER]
#       ,[REGIONNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] where [SUSPECTFRAUD]=1 group by [GENDER]
#       ,[REGIONNAME] order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(3509, 'MALE', 'SNNP'),
#  (2155, 'MALE', 'TIGRAY'),
#  (1902, 'MALE', 'OROMIYA'),
#  (1806, 'MALE', 'SWER'),
#  (1406, 'MALE', 'SOMALE'),
#  (561, 'MALE', 'SIDAMA'),
#  (307, 'MALE', 'AMHARA'),
#  (76, 'MALE', 'BENSHANGUL GUMUZ'),
#  (61, 'MALE', 'ADDIS ABABA'),
#  (25, 'MALE', 'DIRE DAWA'),
#  (15, 'MALE', 'HARARI'),
#  (14, 'MALE', 'GAMBELLA'),
#  (2, 'FEMALE', 'OROMIYA'),
#  (2, 'FEMALE', 'TIGRAY'),
#  (1, 'FEMALE', 'SNNP'),
#  (1, 'FEMALE', 'SWER'),
#  (1, 'MALE', 'AFAR')]

# %%
# %%sql
# SELECT count([TXN_ID]) total_txn,[SUSPECTFRAUD]
#       ,[GENDER]
#       ,[DISTRICTNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by [GENDER],[SUSPECTFRAUD]
#       ,[DISTRICTNAME] order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(119616, 0, 'MALE', 'MERKATO'),
#  (114614, 0, 'MALE', 'NIFAS SILK'),
#  (92356, 0, 'MALE', 'YEKA'),
#  (70780, 0, 'MALE', 'MEGENAGNA'),
#  (61810, 0, 'MALE', 'KIRKOS'),
#  (58570, 0, 'MALE', 'WOLAITA SODO'),
#  (57802, 0, 'MALE', 'KOLFE'),
#  (53790, 0, 'MALE', 'SHASHEMENE'),
#  (50826, 0, 'MALE', 'NEKEMTE'),
#  (48527, 0, 'MALE', 'GONDER'),
#  (47649, 0, 'MALE', 'JIJIGA'),
#  (42302, 0, 'MALE', 'BOLE'),
#  (41185, 0, 'MALE', 'JIMMA'),
#  (40822, 0, 'MALE', 'HAWASSA'),
#  (39241, 0, 'MALE', 'HOSSANA'),
#  (35969, 0, 'MALE', 'DIRE DAWA'),
#  (34424, 0, 'MALE', 'BAHIR DAR'),
#  (31637, 0, 'MALE', 'ARADA'),
#  (31597, 0, 'MALE', 'WOLDIA'),
#  (28717, 0, 'MALE', 'METTU'),
#  (27913, 0, 'MALE', 'SEMERA'),
#  (25711, 0, 'MALE', 'DESSIE'),
#  (23373, 0, 'MALE', 'DEBRE MARKOS'),
#  (20920, 0, 'MALE', 'BALE ROBE'),
#  (20916, 0, 'MALE', 'DEBRE BREHAN'),
#  (20638, 0, 'MALE', 'ADAMA'),
#  (20384, 0, 'MALE', 'AMBO'),
# ...

# %%
# %%sql
# SELECT count([TXN_ID]) total_txn
#       ,[GENDER]
#       ,[DISTRICTNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] where [SUSPECTFRAUD]=1 group by [GENDER]
#       ,[DISTRICTNAME] order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(5401, 'MALE', 'YEKA'),
#  (1721, 'MALE', 'WOLAITA SODO'),
#  (1082, 'MALE', 'WOLDIA'),
#  (920, 'MALE', 'NIFAS SILK'),
#  (793, 'MALE', 'SHASHEMENE'),
#  (408, 'MALE', 'MERKATO'),
#  (383, 'MALE', 'SEMERA'),
#  (276, 'MALE', 'NEKEMTE'),
#  (213, 'MALE', 'SHIRE'),
#  (173, 'MALE', 'METTU'),
#  (126, 'MALE', 'JIJIGA'),
#  (56, 'MALE', 'KOLFE'),
#  (50, 'MALE', 'MEGENAGNA'),
#  (49, 'MALE', 'GONDER'),
#  (38, 'MALE', 'JIMMA'),
#  (30, 'MALE', 'KIRKOS'),
#  (23, 'MALE', 'HOSSANA'),
#  (21, 'MALE', 'HAWASSA'),
#  (19, 'MALE', 'DIRE DAWA'),
#  (13, 'MALE', 'DEBRE MARKOS'),
#  (12, 'MALE', 'MEKELLE'),
#  (8, 'MALE', 'BALE ROBE'),
#  (7, 'MALE', 'DESSIE'),
#  (5, 'MALE', 'ASSELA'),
#  (5, 'FEMALE', 'YEKA'),
#  (4, 'MALE', 'BAHIR DAR'),
#  (3, 'MALE', 'DEBRE BREHAN'),
#  (2, 'MALE', 'DILLA'),
#  (2, 'MALE', 'BOLE'),
#  (1, 'FEMALE', 'WOLDIA')]
